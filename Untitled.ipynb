# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('raw data.csv')

# %%
data.head()
# Out:
#               Pat_ID  Age     Sex Name_InitialMed Date_InitialRx  sBP_t-6  \
# 0   3009000000002127   78  Female      ACEBUTOLOL     2007-12-18      NaN
# 1   2001000000033249   60    Male      ACEBUTOLOL     2010-11-01    150.0
# 2   1003000000071385   84  Female      ACEBUTOLOL     2006-10-18      NaN
# 3  10001000000008854  103  Female      ACEBUTOLOL     2002-04-30      NaN
# 4   1003000000139736   69    Male      ACEBUTOLOL     2006-07-18      NaN
#
#      Date_t-6  sBP_t-5    Date_t-5  sBP_t-4  ...    Date_t+3  sBP_t+4  \
# 0         NaN      NaN         NaN      NaN  ...  2008-02-05    164.0
# 1  2008-01-14    130.0  2008-02-26    150.0  ...  2012-01-17    153.0
# 2         NaN      NaN         NaN      NaN  ...  2007-08-01    162.0
# 3         NaN      NaN         NaN      NaN  ...  2003-07-08      NaN
# 4         NaN      NaN         NaN    188.0  ...  2006-11-07    200.0
#
#      Date_t+4  sBP_t+5    Date_t+5  sBP_t+6    Date_t+6  Before_BP_Ave  \
# ...

# %%
data.describe()
# Out:
#              Pat_ID            Age       sBP_t-6       sBP_t-5       sBP_t-4  \
# count  1.557130e+05  155713.000000  75759.000000  85376.000000  96800.000000
# mean   4.903816e+15      68.847135    136.815032    137.131454    137.381632
# std    2.870017e+15      14.617127     18.012205     48.257011     45.708302
# min    1.001000e+15       2.000000     60.000000      1.000000      2.000000
# 25%    3.009000e+15      59.000000    125.000000    125.000000    125.000000
# 50%    5.001001e+15      69.000000    136.000000    136.000000    136.000000
# 75%    7.001001e+15      80.000000    148.000000    148.000000    148.000000
# max    1.300100e+16     116.000000    264.000000  13090.000000  13068.000000
#
#              sBP_t-3        sBP_t-2        sBP_t-1         sBP_t0  \
# count  110712.000000  128615.000000  155713.000000  155682.000000
# mean      137.760234     138.632049     139.094957     141.248924
# std        43.139766      76.017981      19.643050      75.708180
# ...

# %%
data.groupby('Name_InitialMed').mean()
# Out:
#                                                         Pat_ID        Age  \
# Name_InitialMed
# ACEBUTOLOL                                        5.043026e+15  76.773234
# ALISKIREN                                         4.235682e+15  71.832636
# ALISKIREN AND HYDROCHLOROTHIAZIDE                 4.501375e+15  66.750000
# AMILORIDE                                         3.001857e+15  72.000000
# AMLODIPINE                                        4.650644e+15  70.456638
# ATENOLOL                                          5.550657e+15  68.954768
# ATENOLOL AND OTHER DIURETICS                      4.724793e+15  68.632979
# BENAZEPRIL                                        3.501667e+15  69.791667
# BENDROFLUMETHIAZIDE                               5.001001e+15  69.000000
# BETAXOLOL                                         5.930238e+15  81.690476
# BISOPROLOL                                        4.673846e+15  71.165348
# ...

# %%
sns.factorplot('sBP_t-6', data = data, hue = 'Age', kind = 'count', units = 50, )

# %%
data['sBP_t-6'].hist( bins = 50)

# %%
data['Age'].hist(bins = 25)

# %%
important_features = data[['Age', 'Sex', 'Name_InitialMed', 'Delta_Before-After']]

# %%
important_features.head()
# Out:
#    Age     Sex Name_InitialMed  Delta_Before-After
# 0   78  Female      ACEBUTOLOL          -12.476190
# 1   60    Male      ACEBUTOLOL          -20.000000
# 2   84  Female      ACEBUTOLOL          -55.333333
# 3  103  Female      ACEBUTOLOL          -55.333333
# 4   69    Male      ACEBUTOLOL          -60.000000

# %%
important_features.to_csv('important_features.csv')

# %%
unique_data = pd.read_csv('important_features.csv')

# %%
from sklearn.preprocessing import OneHotEncoder 
from sklearn.compose import ColumnTransformer

# %%
import numpy as np

# %%
columnTransformer = ColumnTransformer([('encoder', 
                                        OneHotEncoder(), 
                                        [0])], 
                                      remainder='passthrough') 
  
transformed_data = np.array(columnTransformer.fit_transform(unique_data), dtype = np.str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in _hstack(self, Xs)
#     630                                             force_all_finite=False)
# --> 631                                 for X in Xs]
#     632             except ValueError:
#
# ~\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py in <listcomp>(.0)
#     630                                             force_all_finite=False)
# --> 631                                 for X in Xs]
#     632             except ValueError:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
unique_data.head()
# Out:
#    Unnamed: 0  Age     Sex Name_InitialMed  Delta_Before-After
# 0           0   78  Female      ACEBUTOLOL          -12.476190
# 1           1   60    Male      ACEBUTOLOL          -20.000000
# 2           2   84  Female      ACEBUTOLOL          -55.333333
# 3           3  103  Female      ACEBUTOLOL          -55.333333
# 4           4   69    Male      ACEBUTOLOL          -60.000000

# %%
important_features.dtypes
# Out:
# Age                     int64
# Sex                    object
# Name_InitialMed        object
# Delta_Before-After    float64
# dtype: object

# %%
important_features['Sex'] = important_features['Sex'].astype(str)
important_features['Name_InitialMed'] = important_features['Name_InitialMed'].astype(str)
# Out:
# C:\Users\gupta\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\gupta\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
important_features.dtypes
# Out:
# Age                     int64
# Sex                    object
# Name_InitialMed        object
# Delta_Before-After    float64
# dtype: object

# %%
boolean_list = important_features['Sex'] == 'FEMALE'
important_features['Sex'][boolean_list] = 'Female'
# Out:
# C:\Users\gupta\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\gupta\Anaconda3\lib\site-packages\pandas\core\generic.py:8682: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\gupta\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2910: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
boolean_list = important_features['Sex'] == 'MALE'
important_features['Sex'][boolean_list] = 'Male'
# Out:
# C:\Users\gupta\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\gupta\Anaconda3\lib\site-packages\pandas\core\generic.py:8682: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\gupta\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2910: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
list_boolean = important_features['Sex'] == 'nan'
important_features['Sex'][list_boolean] = np.nan
# Out:
# C:\Users\gupta\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\gupta\Anaconda3\lib\site-packages\pandas\core\generic.py:8682: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\gupta\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2910: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
important_features['Sex'].hist()

# %%
newDF = important_features['Sex'].dropna()

# %%
important_features['Sex'] = newDF
# Out:
# C:\Users\gupta\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
important_features.head()
# Out:
#    Age     Sex Name_InitialMed  Delta_Before-After
# 0   78  Female      ACEBUTOLOL          -12.476190
# 1   60    Male      ACEBUTOLOL          -20.000000
# 2   84  Female      ACEBUTOLOL          -55.333333
# 3  103  Female      ACEBUTOLOL          -55.333333
# 4   69    Male      ACEBUTOLOL          -60.000000

# %%
booleans = []
for item in important_features['Sex']:
    if type(item) == float:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
important_features['Sex'][booleans]
# Out:
# 35103     NaN
# 55292     NaN
# 72989     NaN
# 117419    NaN
# 152522    NaN
# Name: Sex, dtype: object

# %%
boolean_list = important_features['Sex'] == 'Unknown'
important_features['Sex'][boolean_list]
# Out:
# 61277    Unknown
# Name: Sex, dtype: object

# %%
important_features['Sex'].hist()

# %%
le = LabelEncoder() 
  
important_features['Sex']= le.fit_transform(important_features['Sex']) 
important_features['Name_InitialMed']= le.fit_transform(important_features['Name_InitialMed'])

important_features.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     112         try:
# --> 113             res = _encode_python(values, uniques, encode)
#     114         except TypeError:
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      60     if uniques is None:
# ---> 61         uniques = sorted(set(values))
#      62         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-49f6f0f34e80> in <module>()
#       1 le = LabelEncoder()
#       2
# ...
